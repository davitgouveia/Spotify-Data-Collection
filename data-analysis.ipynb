# %% [markdown]
# # Imports and data collection

# %% [markdown]
# ## Imports the librarys

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reads the Dataframe

# %%
df_spotify = pd.read_csv('https://raw.githubusercontent.com/MateusViotto/Machine-Learning-with-Python/main/Datasets/Spotify-dataset.csv', index_col=0).dropna().drop_duplicates()

df_spotify.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Exploratory data analysis is an approach to analyzing data sets and summarizing their key characteristics, usually with visual methods.

# %% [markdown]
# ## Shows the shape of the DataFrame

# %%
df_spotify.shape
# Out:
# (113549, 20)

# %% [markdown]
# ## Shows the columns of the DataFrame

# %%
df_spotify.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %% [markdown]
# ## Infos about the DataFrame

# %%
df_spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113549 entries, 0 to 113999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          113549 non-null  object
#  1   artists           113549 non-null  object
#  2   album_name        113549 non-null  object
#  3   track_name        113549 non-null  object
#  4   popularity        113549 non-null  int64
#  5   duration_ms       113549 non-null  int64
#  6   explicit          113549 non-null  bool
#  7   danceability      113549 non-null  float64
#  8   energy            113549 non-null  float64
#  9   key               113549 non-null  int64
#  10  loudness          113549 non-null  float64
#  11  mode              113549 non-null  int64
#  12  speechiness       113549 non-null  float64
#  13  acousticness      113549 non-null  float64
#  14  instrumentalness  113549 non-null  float64
#  15  liveness          113549 non-null  float64
# ...

# %% [markdown]
# ## Describes the DataFrame

# %%
df_spotify.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  113549.000000  1.135490e+05  113549.000000  113549.000000
# mean       33.324433  2.280814e+05       0.567031       0.642091
# std        22.283855  1.064131e+05       0.173409       0.251053
# min         0.000000  8.586000e+03       0.000000       0.000000
# 25%        17.000000  1.741840e+05       0.456000       0.473000
# 50%        35.000000  2.130000e+05       0.580000       0.685000
# 75%        50.000000  2.615880e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  113549.000000  113549.000000  113549.000000  113549.000000
# mean        5.309452      -8.243408       0.637866       0.084674
# std         3.560147       5.011422       0.480620       0.105762
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %% [markdown]
# ## Checks if there is a null value

# %%
df_spotify.isnull().sum()
# Out:
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %% [markdown]
# # First Analysis

# %% [markdown]
# ## Top 100 Tracks

# %%
df_toptracks = df_spotify.sort_values('popularity',ascending = False).head(100)

df_toptracks
# Out:
#                      track_id                     artists  \
# 81051  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 20001  3nqQXoyQOWXiESFLlDF1hG        Sam Smith;Kim Petras
# 51664  2tTmW7RDtMQtBk7m2rYeSw            Bizarrap;Quevedo
# 68303  5ww2BF9slyYgNOk37BlC4u               Manuel Turizo
# 81210  4uUG5RXrOk84mYEfFvj3cK     David Guetta;Bebe Rexha
# ...                       ...                         ...
# 81803  75FEaRjZTKLhTrFGsfMUXR                   Kate Bush
# 51259  38T0tPVZHcPZyhtOcCP7pF                   Lil Nas X
# 23002  4zN21mbAuaD0WqtmaTZZeP  James Hype;Miggy Dela Rosa
# 51352  1PckUlxKqWQs3RlWXVBLw3                       Lizzo
# 81053  0u2P5u6lvoDfwTYjAADbn4        Billie Eilish;Khalid
#
#                                            album_name  \
# 81051                       Unholy (feat. Kim Petras)
# 20001                       Unholy (feat. Kim Petras)
# 51664           Quevedo: Bzrp Music Sessions, Vol. 52
# ...

# %%
df_toptracks_view = df_toptracks[['track_name', 'popularity']].copy()

df_toptracks_view.rename(columns={"track_name":"Tracks","popularity":"Popularity"},inplace=True)

df_toptracks_view
# Out:
#                                                Tracks  Popularity
# 81051                       Unholy (feat. Kim Petras)         100
# 20001                       Unholy (feat. Kim Petras)         100
# 51664           Quevedo: Bzrp Music Sessions, Vol. 52          99
# 68303                                      La Bachata          98
# 81210                                 I'm Good (Blue)          98
# ...                                               ...         ...
# 81803          Running Up That Hill (A Deal With God)          90
# 51259  STAR WALKIN' (League of Legends Worlds Anthem)          90
# 23002                                         Ferrari          90
# 51352                                 About Damn Time          89
# 81053                            lovely (with Khalid)          89
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Most Popular Artists

# %%
# Assuming your dataframe is named 'df' with columns 'artist' and 'popularity'
df_grouped_artist = df_spotify.groupby('artists')['popularity'].sum().reset_index()

# Sort the dataframe based on the sum of popularity in descending order
df_artist_sorted = df_grouped_artist.sort_values(by='popularity', ascending=False)

# Display the most popular artists
most_popular_artists = df_artist_sorted['artists']
most_popular_artists.head(100)
# Out:
# 26983          The Beatles
# 16049          Linkin Park
# 2783                   BTS
# 21810        Prateek Kuhad
# 8647         Elvis Presley
#                ...
# 6509          Daddy Yankee
# 8607        Ellie Goulding
# 24446            Scorpions
# 4076     Breaking Benjamin
# 797                  Aimer
# Name: artists, Length: 100, dtype: object

# %% [markdown]
# ## Most Popular Genres

# %%
# Assuming your dataframe is named 'df' with columns 'artist' and 'popularity'
df_grouped_genres = df_spotify.groupby('track_genre')['popularity'].sum().reset_index()

# Sort the dataframe based on the sum of popularity in descending order
df_genres_sorted = df_grouped_genres.sort_values(by='popularity', ascending=False)

display(df_genres_sorted)

# Display the most popular artists
most_popular_genres = df_genres_sorted['track_genre']
most_popular_genres.head(100)
# Out:
#        track_genre  popularity
# 81        pop-film       59221
# 65           k-pop       56850
# 15           chill       53651
# 94             sad       52379
# 44          grunge       49533
# ..             ...         ...
# 13   chicago-house       12309
# 24  detroit-techno       11161
# 67           latin        8280
# 93         romance        3209
# 59         iranian        2198
#
# [114 rows x 2 columns]
# 81      pop-film
# 65         k-pop
# 15         chill
# 94           sad
# 44        grunge
#          ...
# 46         happy
# 78         party
# 88        reggae
# 10     breakbeat
# 108        tango
# Name: track_genre, Length: 100, dtype: object

# %% [markdown]
# ## Musics by Artists

# %%
df_tracksbyArtists = df_spotify["artists"].value_counts()

print(df_tracksbyArtists[:].sum())

df_tracksbyArtists
# Out:
# 113549
# The Beatles                      279
# George Jones                     260
# Stevie Wonder                    235
# Linkin Park                      224
# Ella Fitzgerald                  221
#                                 ...
# Mr. Probz;Robin Schulz             1
# Keanu Silva;Jhn McFly;Marissa      1
# Alan Walker;Hans Zimmer            1
# Triplo Max                         1
# Jesus Culture                      1
# Name: artists, Length: 31437, dtype: int64

# %% [markdown]
# ## Musics by Genre

# %%
df_tracksbyGenre = df_spotify["track_genre"].value_counts()

df_tracksbyGenre
# Out:
# acoustic       1000
# emo            1000
# rock-n-roll    1000
# reggaeton      1000
# disco          1000
#                ...
# honky-tonk      981
# dance           965
# german          963
# classical       933
# romance         904
# Name: track_genre, Length: 114, dtype: int64

# %% [markdown]
# ## Top 10 Longest Tracks

# %%
df_longestTracks = df_spotify[["track_name","duration_ms"]].sort_values(by="duration_ms",ascending=False)[:10]

df_longestTracks
# Out:
#                                           track_name  duration_ms
# 73617                       Unity (Voyage Mix) Pt. 1      5237295
# 10935         Crossing Wires 002 - Continuous DJ Mix      4789026
# 24348          The Lab 03 - Continuous DJ Mix Part 1      4730302
# 73840            Amnesia Ibiza Underground 10 DJ Mix      4563897
# 13344     House of Om - Mark Farina - Continuous Mix      4447520
# 13245                 Live In Tokyo - Continuous Mix      4339826
# 13195                        Greenhouse Construction      4334721
# 27926   NQ State of Mind, Vol. 1 - Continuous DJ Mix      4246206
# 101390                            Ocean Waves Sounds      4120258
# 45063                   Internal Flight (Remastered)      3876276

# %% [markdown]
# ## Top 10 Most Danceable, Loudness, Explicit, Acousticness, instrumentalness and  liveness Tracks

# %% [markdown]
# df_mostDanceableTracks = df_spotify[["track_name","artists","danceability"]].sort_values(by="danceability",ascending=False)[:10]
# df_mostLoudness = df_spotify[["track_name","artists","loudness"]].sort_values(by="loudness",ascending=False)[:10]
# df_mostSpeechiness = df_spotify[["track_name","artists","speechiness"]].sort_values(by="speechiness",ascending=False)[:10]
# df_mostAcousticness = df_spotify[["track_name","artists","acousticness"]].sort_values(by="acousticness",ascending=False)[:10]
# df_mostInstrumentalness = df_spotify[["track_name","artists","instrumentalness"]].sort_values(by="instrumentalness",ascending=False)[:10]
# ds_mostLiveness = df_spotify[["track_name","artists","liveness"]].sort_values(by="liveness",ascending=False)[:10]

# %% [markdown]
# window, graphs = plt.subplots(nrows=3, ncols=2, figsize=(20,10))
#
# sns.barplot(data=df_mostDanceableTracks, x="track_name", y="danceability", ax=graphs[0][0])
# sns.barplot(data=df_mostLoudness, x="track_name", y="loudness", ax=graphs[0][1])
# sns.barplot(data=df_mostSpeechiness, x="track_name", y="speechiness", ax=graphs[1][0])
# sns.barplot(data=df_mostAcousticness, x="track_name", y="acousticness", ax=graphs[1][1])
# sns.barplot(data=df_mostInstrumentalness, x="track_name", y="instrumentalness", ax=graphs[2][0])
# sns.barplot(data=ds_mostLiveness, x="track_name", y="liveness", ax=graphs[2][1])
#
# window

# %% [markdown]
# ### Most Danceable Tracks

# %%
df_mostDanceableTracks
# Out:
#                                                track_name  \
# 111635                                           Sol Clap
# 66576                                       Medicaid Baby
# 24916                                         Inspiration
# 73374                                      Daily Routines
# 66793   Featuring Mixx Master Lee, Red Rum & J. Smoov ...
# 13353                                             Bitches
# 94006                                  Dancing in My Room
# 13145                                   Plastik Fantastik
# 13039                     The Underground - Hatiras Remix
# 14119                     The Soccer Song (Football Song)
#
#                                    artists  danceability
# 111635                             Quantic         0.985
# 66576                    That Girl Lay Lay         0.984
# 24916                         Delano Smith         0.983
# 73374                      Oliver Schories         0.982
# ...

# %% [markdown]
# ### Most Loudness Tracks

# %%
df_mostLoudness
# Out:
#                                               track_name          artists  \
# 17574                                         Fate Dance  Five Star Hotel
# 59225                                 Islamic Capitalism           Najand
# 38840                                          Time Bomb    The Red Pears
# 59337                         A Better World Is Possible           Najand
# 37738                 TIPO HARIEL - SEI QUE E RARIDADE -   DJ BRUNO PRADO
# 17895                                        Malfunction     Free Refills
# 59833                             Preaching for the Deaf           Najand
# 37548  AUTOMOTIVO DAS PIRANHA - VEM COMER MINHA TCHEC...         DJ Arana
# 17788                                           The Mall     Free Refills
# 69699                       Mel Nattu Isai (From "Jodi")          Sujatha
#
#        loudness
# 17574     4.532
# 59225     3.156
# 38840     2.574
# 59337     1.864
# 37738     1.821
# 17895     1.795
# 59833     1.700
# ...

# %% [markdown]
# ###  Most Speechiness Tracks

# %%
df_mostSpeechiness
# Out:
#                      track_name              artists  speechiness
# 18152              turd whistle          Tenacious D        0.965
# 18530     Less and Less Radical        Patton Oswalt        0.963
# 18504            The Real World             Tom Papa        0.963
# 18137     Get Rid of That Joke!          Dan Cummins        0.962
# 18227         Parents and Pills        Patton Oswalt        0.962
# 18666           Angry Young Men             Tom Papa        0.962
# 18674               Morning Tom             Tom Papa        0.962
# 18432              Chemotherapy      Robert Schimmel        0.962
# 18663        The Human Contract             Tom Papa        0.962
# 18739  Christmas is My Favorite  Larry The Cable Guy        0.961

# %% [markdown]
# ### Most Acousticness Tracks

# %%
df_mostAcousticness
# Out:
#                                                track_name  \
# 4179                                        The Departure
# 101972                       Nap in the Afternoon Box Fan
# 79423                                         Fusionnelle
# 79808                                               Fiore
# 16872                                  Adagio in F, K.410
# 79886                                             Konbini
# 45616                              Lament in Tremelo Form
# 39031   Vom Himmel hoch da komm ich her, BWV 769 - Orc...
# 26387                          Two Worlds (From "Tarzan")
# 93907                                На последнюю пятерку
#
#                                                   artists  acousticness
# 4179                                          Max Richter         0.996
# 101972  Binaural Beats;White Noise Babies;Binaural Bea...         0.996
# 79423                      Omri Grummet;Nadav Amir-Himmel         0.996
# ...

# %% [markdown]
# ###  Instrumentalness Tracks

# %%
df_mostInstrumentalness
# Out:
#                                        track_name  \
# 101867       Hair Dryer (Baby White Noise Series)
# 101050                          Brown Sleep Noise
# 101892                     Pink Noise For Sleep 8
# 101919                                 Hair Dryer
# 101376  Clean White Noise - Loopable with no fade
# 101566                                   Fan Whir
# 113688         Ruido Rosa Puro - Una Hora Versión
# 101575           Large Industrial Air Conditioner
# 101875                           Hidden Waterfall
# 101735                        Brown Noise 148 LPF
#
#                                                   artists  instrumentalness
# 101867                                   Baby Sweet Dream               1.0
# 101050                                      Sleep Miracle               1.0
# 101892                                           Granular               1.0
# 101919                                   Baby Sweet Dream               1.0
# ...

# %% [markdown]
# ### Most Liveness Tracks

# %%
ds_mostLiveness
# Out:
#                                                track_name  \
# 90597   Solito Con las Estrellas / Yolanda (with Jorge...
# 77642   Fortaleza / Tempo / Lugarzinho (Participação e...
# 84818           Another Brick in the Wall, (Pt. 2) - Live
# 12329                                   介乎法國與旺角的詩意 - Live
# 101581         Summer Rain Sleep Relaxation Sounds, Pt. 2
# 44715   In the End - Live at Live 8, Benjamin Franklin...
# 46245                                      Wonderful Days
# 79286   Shameless - Live at Yankee Stadium, Bronx, NY ...
# 100892    El Genio Del Dub - Versión Remasterizada (Live)
# 22388                      When the World Explodes - Live
#
#                                                   artists  liveness
# 90597       Marco Antonio Muñiz;Jorge Muñiz;Mariano Perez     1.000
# 77642                                       Ferrugem;Tiee     1.000
# 84818                                          Pink Floyd     0.997
# ...
